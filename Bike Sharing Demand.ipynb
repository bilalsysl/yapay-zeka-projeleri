# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('train.csv')
df2=pd.read_csv('test.csv')

# %%
df1
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 0      14.395        81     0.0000       3          13     16
# 1      13.635        80     0.0000       8          32     40
# 2      13.635        80     0.0000       5          27     32
# 3      14.395        75     0.0000       3          10     13
# 4      14.395        75     0.0000       0           1      1
# ...       ...       ...        ...     ...         ...    ...
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88
#
# [10886 rows x 12 columns]

# %%
df2
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-20 00:00:00       1        0           1        1  10.66
# 1     2011-01-20 01:00:00       1        0           1        1  10.66
# 2     2011-01-20 02:00:00       1        0           1        1  10.66
# 3     2011-01-20 03:00:00       1        0           1        1  10.66
# 4     2011-01-20 04:00:00       1        0           1        1  10.66
# ...                   ...     ...      ...         ...      ...    ...
# 6488  2012-12-31 19:00:00       1        0           1        2  10.66
# 6489  2012-12-31 20:00:00       1        0           1        2  10.66
# 6490  2012-12-31 21:00:00       1        0           1        1  10.66
# 6491  2012-12-31 22:00:00       1        0           1        1  10.66
# 6492  2012-12-31 23:00:00       1        0           1        1  10.66
#
#        atemp  humidity  windspeed
# 0     11.365        56    26.0027
# 1     13.635        56     0.0000
# 2     13.635        56     0.0000
# 3     12.880        56    11.0014
# 4     12.880        56    11.0014
# ...      ...       ...        ...
# 6488  12.880        60    11.0014
# 6489  12.880        60    11.0014
# 6490  12.880        60    11.0014
# 6491  13.635        56     8.9981
# 6492  13.635        65     8.9981
#
# [6493 rows x 9 columns]

# %%
df1['datetime']=pd.to_datetime(df1['datetime'])
df1['Yıl']=df1['datetime'].dt.year
df1['Ay']=df1['datetime'].dt.month
df1['Gun']=df1['datetime'].dt.dayofweek
df1['Saat']=df1['datetime'].dt.hour
df1['Dakika']=df1['datetime'].dt.minute

# %%
df1.drop(['datetime','casual','registered'],axis=1,inplace=True)

# %%
df2['datetime']=pd.to_datetime(df2['datetime'])
df2['Yıl']=df2['datetime'].dt.year
df2['Ay']=df2['datetime'].dt.month
df2['Gun']=df2['datetime'].dt.dayofweek
df2['Saat']=df2['datetime'].dt.hour
df2['Dakika']=df2['datetime'].dt.minute

# %%
h=df2['datetime']

# %%
df2.drop('datetime',axis=1,inplace=True)

# %%
x=df1.drop('count',axis=1)
y=df1['count']

# %%
y.value_counts()
# Out:
# 5      169
# 4      149
# 3      144
# 6      135
# 2      132
#       ...
# 801      1
# 629      1
# 825      1
# 589      1
# 636      1
# Name: count, Length: 822, dtype: int64

# %%
from sklearn.model_selection import train_test_split as tts

# %%
x_train,x_test,y_train,y_test=tts(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
y_pred=gbr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8547665360326899

# %%
(mean_squared_error(y_test,y_pred))**0.5
# Out:
# 69.0340257398648

# %%
tahmin=gbr.predict(df2)

# %%
df2['count']=tahmin

# %%
df2['count']=abs(df2['count'])

# %%
df2['datetime']=h

# %%
df2[['datetime','count']].to_csv('bike.csv',index=False)

# %%
df2
# Out:
#       season  holiday  workingday  weather   temp   atemp  humidity  \
# 0          1        0           1        1  10.66  11.365        56
# 1          1        0           1        1  10.66  13.635        56
# 2          1        0           1        1  10.66  13.635        56
# 3          1        0           1        1  10.66  12.880        56
# 4          1        0           1        1  10.66  12.880        56
# ...      ...      ...         ...      ...    ...     ...       ...
# 6488       1        0           1        2  10.66  12.880        60
# 6489       1        0           1        2  10.66  12.880        60
# 6490       1        0           1        1  10.66  12.880        60
# 6491       1        0           1        1  10.66  13.635        56
# 6492       1        0           1        1  10.66  13.635        65
#
#       windspeed   Yıl  Ay  Gun  Saat  Dakika       count            datetime
# 0       26.0027  2011   1    3     0       0    6.019840 2011-01-20 00:00:00
# 1        0.0000  2011   1    3     1       0    5.692213 2011-01-20 01:00:00
# 2        0.0000  2011   1    3     2       0    9.239086 2011-01-20 02:00:00
# 3       11.0014  2011   1    3     3       0   12.210503 2011-01-20 03:00:00
# 4       11.0014  2011   1    3     4       0   12.210503 2011-01-20 04:00:00
# ...         ...   ...  ..  ...   ...     ...         ...                 ...
# 6488    11.0014  2012  12    0    19       0  339.904062 2012-12-31 19:00:00
# 6489    11.0014  2012  12    0    20       0  236.911541 2012-12-31 20:00:00
# 6490    11.0014  2012  12    0    21       0  192.124893 2012-12-31 21:00:00
# 6491     8.9981  2012  12    0    22       0  141.386869 2012-12-31 22:00:00
# 6492     8.9981  2012  12    0    23       0  105.418399 2012-12-31 23:00:00
#
# [6493 rows x 15 columns]
